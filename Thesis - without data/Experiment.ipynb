# %%
# Array and dataframe handling.
import pandas as pd
import numpy as np
# Statistics and modeling.
from scipy import stats
import statsmodels.formula.api as smf
# Utility.
from lib.utils import clean_cats, stepwise, classify, mixed

# %% [markdown]
# ## Get Data and combine

# %%
anchor_p1 = pd.read_stata("dta/Data/Stata/anchor13_capi.dta")
anchor_p2 = pd.read_stata("dta/Data/Stata/anchor13_cati.dta")
partner_df = pd.read_stata("dta/Data/Stata/partner13.dta")

# Pre cleaning.
anchor_p1_cleaned = clean_cats(anchor_p1, ["sat5", "sex_gen", "val1i3", "sex8"])
anchor_p2_cleaned = clean_cats(anchor_p2, ["sat5", "sex_gen", "val1i3", "sex8"])
partner_df_cleaned = clean_cats(partner_df, ["psat5", "psex", "pval1i3"])

# Combine anchors.
anchor_df = pd.concat([anchor_p1_cleaned, anchor_p2_cleaned])
assert anchor_df.shape[0] == anchor_p1_cleaned.shape[0] +  anchor_p2_cleaned.shape[0], "Length of combined df not sum of single dfs!"

# Join anchors with partners.
data_df = anchor_df.join(partner_df_cleaned.set_index("id"), on=("id"), how="inner", rsuffix="_p")
assert data_df.shape[0] == 2385, "There should be 2385 partner-anchors combos!"

transformed_df = data_df.copy()

# Filter
# same sex couples.
n_all = transformed_df.shape[0]
transformed_df = transformed_df[transformed_df["sex_gen"] != transformed_df["psex"]]
n_hetero = transformed_df.shape[0]
n_homo = n_all - n_hetero
# Create variables.
# Sexual satisfaction by gender.
transformed_df = transformed_df.dropna(subset=["psex", "sex_gen", "sat5", "psat5"])
transformed_df["fsat5"] = np.where(transformed_df["sex_gen"] == 2, transformed_df["sat5"], transformed_df["psat5"])
transformed_df["msat5"] = np.where(transformed_df["sex_gen"] == 1, transformed_df["sat5"], transformed_df["psat5"])
# Difference of satisfaction.
transformed_df["difsat5"] = transformed_df["fsat5"] - transformed_df["msat5"]
# Traditional values by gender.
transformed_df = transformed_df.dropna(subset=["val1i3", "pval1i3"])
transformed_df["fval1i3"] = np.where(transformed_df["sex_gen"] == 2, transformed_df["val1i3"], transformed_df["pval1i3"])
transformed_df["mval1i3"] = np.where(transformed_df["sex_gen"] == 1, transformed_df["val1i3"], transformed_df["pval1i3"])
# Difference of values.
transformed_df["difval1i3"] = transformed_df["fval1i3"] - transformed_df["mval1i3"]

# Age
transformed_df = transformed_df.dropna(subset=["age", "page"])
transformed_df["fage"] = np.where(transformed_df["sex_gen"] == 2, transformed_df["age"], transformed_df["page"]).astype(int)
transformed_df["mage"] = np.where(transformed_df["sex_gen"] == 1, transformed_df["age"], transformed_df["page"]).astype(int)


# Categorisation of values by gender.
transformed_df["ftrad"] = transformed_df["fval1i3"] >= 3
transformed_df["mtrad"] = transformed_df["mval1i3"] >= 3

transformed_df["fegal"] = transformed_df["fval1i3"] < 3
transformed_df["megal"] = transformed_df["mval1i3"] < 3

# Relationship combination of values.
transformed_df["both"] = transformed_df.apply(classify, axis=1)
transformed_df["both2"] = transformed_df.apply(mixed, axis=1)

# Some more cleanning.
transformed_df = transformed_df.dropna(subset=["sex8"])
transformed_df["sex8"] = transformed_df["sex8"].astype(int)

print(f"{len(transformed_df)} partner-anchors")

# More cleaning.
final_df = transformed_df[transformed_df["reldur"] != "-7 Incomplete data"].copy()
final_df["reldur"] = final_df["reldur"].astype(int)
# Out:
# 1826 partner-anchors

# %% [markdown]
# ## Individual regressions

# %%
stepwise("fsat5", ["fegal", "reldur", "fage", "sex8" ], final_df)
# Out:
# Step 0:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  fsat5   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.281
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):              0.131
# Time:                        22:34:38   Log-Likelihood:                -4163.5
# No. Observations:                1812   AIC:                             8331.
# Df Residuals:                    1810   BIC:                             8342.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         6.7136      0.085     78.616      0.000       6.546       6.881
# fegal[T.True]    -0.1722      0.114     -1.510      0.131      -0.396       0.051
# ==============================================================================
# Omnibus:                      153.019   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              192.552
# Skew:                          -0.796   Prob(JB):                     1.54e-42
# Kurtosis:                       3.134   Cond. No.                         2.79
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Step 1:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  fsat5   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     20.29
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):           1.93e-09
# Time:                        22:34:38   Log-Likelihood:                -4144.6
# No. Observations:                1812   AIC:                             8295.
# Df Residuals:                    1809   BIC:                             8312.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         7.2253      0.118     61.082      0.000       6.993       7.457
# fegal[T.True]    -0.2146      0.113     -1.898      0.058      -0.436       0.007
# reldur           -0.0034      0.001     -6.185      0.000      -0.004      -0.002
# ==============================================================================
# Omnibus:                      153.596   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              193.457
# Skew:                          -0.798   Prob(JB):                     9.80e-43
# Kurtosis:                       3.133   Cond. No.                         461.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Step 2:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  fsat5   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     27.71
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):           1.62e-17
# Time:                        22:34:38   Log-Likelihood:                -4123.9
# No. Observations:                1812   AIC:                             8256.
# Df Residuals:                    1808   BIC:                             8278.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         8.8269      0.274     32.166      0.000       8.289       9.365
# fegal[T.True]    -0.2685      0.112     -2.394      0.017      -0.488      -0.049
# reldur            0.0005      0.001      0.638      0.523      -0.001       0.002
# fage             -0.0606      0.009     -6.452      0.000      -0.079      -0.042
# ==============================================================================
# Omnibus:                      140.036   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              172.885
# Skew:                          -0.755   Prob(JB):                     2.87e-38
# Kurtosis:                       3.107   Cond. No.                         904.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Step 3:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  fsat5   R-squared:                       0.283
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     178.2
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):          8.96e-129
# Time:                        22:34:38   Log-Likelihood:                -3863.4
# No. Observations:                1812   AIC:                             7737.
# Df Residuals:                    1807   BIC:                             7764.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         4.0107      0.308     13.009      0.000       3.406       4.615
# fegal[T.True]    -0.0998      0.097     -1.024      0.306      -0.291       0.091
# reldur            0.0012      0.001      1.672      0.095      -0.000       0.003
# fage             -0.0187      0.008     -2.252      0.024      -0.035      -0.002
# sex8              0.9283      0.038     24.535      0.000       0.854       1.002
# ==============================================================================
# Omnibus:                       96.328   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              110.715
# Skew:                          -0.589   Prob(JB):                     9.09e-25
# Kurtosis:                       3.281   Cond. No.                     1.17e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
stepwise("msat5", ["megal", "reldur", "mage", "sex8" ], final_df)
# Out:
# Step 0:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  msat5   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.06181
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):              0.804
# Time:                        22:34:38   Log-Likelihood:                -4270.2
# No. Observations:                1812   AIC:                             8544.
# Df Residuals:                    1810   BIC:                             8555.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         6.3709      0.093     68.502      0.000       6.188       6.553
# megal[T.True]     0.0303      0.122      0.249      0.804      -0.209       0.269
# ==============================================================================
# Omnibus:                      132.986   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              159.838
# Skew:                          -0.718   Prob(JB):                     1.96e-35
# Kurtosis:                       2.769   Cond. No.                         2.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Step 1:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  msat5   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     36.45
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):           3.03e-16
# Time:                        22:34:38   Log-Likelihood:                -4234.4
# No. Observations:                1812   AIC:                             8475.
# Df Residuals:                    1809   BIC:                             8491.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         7.0963      0.125     56.916      0.000       6.852       7.341
# megal[T.True]    -0.0020      0.119     -0.016      0.987      -0.236       0.232
# reldur           -0.0049      0.001     -8.534      0.000      -0.006      -0.004
# ==============================================================================
# Omnibus:                      127.575   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              153.404
# Skew:                          -0.707   Prob(JB):                     4.88e-34
# Kurtosis:                       2.815   Cond. No.                         464.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Step 2:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  msat5   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     30.29
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):           4.22e-19
# Time:                        22:34:38   Log-Likelihood:                -4225.8
# No. Observations:                1812   AIC:                             8460.
# Df Residuals:                    1808   BIC:                             8482.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         8.1115      0.274     29.626      0.000       7.575       8.648
# megal[T.True]    -0.0044      0.119     -0.037      0.971      -0.238       0.229
# reldur           -0.0025      0.001     -3.081      0.002      -0.004      -0.001
# mage             -0.0361      0.009     -4.160      0.000      -0.053      -0.019
# ==============================================================================
# Omnibus:                      118.128   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              139.905
# Skew:                          -0.674   Prob(JB):                     4.17e-31
# Kurtosis:                       2.814   Cond. No.                         854.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Step 3:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  msat5   R-squared:                       0.313
# Model:                            OLS   Adj. R-squared:                  0.312
# Method:                 Least Squares   F-statistic:                     206.2
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):          7.75e-146
# Time:                        22:34:38   Log-Likelihood:                -3929.5
# No. Observations:                1812   AIC:                             7869.
# Df Residuals:                    1807   BIC:                             7897.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         2.9041      0.305      9.530      0.000       2.306       3.502
# megal[T.True]     0.1736      0.101      1.714      0.087      -0.025       0.372
# reldur           -0.0013      0.001     -1.839      0.066      -0.003    8.42e-05
# mage              0.0014      0.008      0.188      0.851      -0.013       0.016
# sex8              1.0347      0.039     26.440      0.000       0.958       1.111
# ==============================================================================
# Omnibus:                       51.540   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.264
# Skew:                          -0.418   Prob(JB):                     9.99e-13
# Kurtosis:                       3.184   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Relationship regressions

# %%
stepwise("fsat5", ['C(both, Treatment(reference="egal/egal"))', "reldur", "fage", "sex8" ], final_df)
# Out:
# Step 0:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  fsat5   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.7811
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):              0.504
# Time:                        22:34:38   Log-Likelihood:                -4163.5
# No. Observations:                1812   AIC:                             8335.
# Df Residuals:                    1808   BIC:                             8357.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    6.5326      0.093     70.354      0.000       6.351       6.715
# C(both, Treatment(reference="egal/egal"))[T.fegal/mtrad]     0.0258      0.160      0.161      0.872      -0.288       0.340
# C(both, Treatment(reference="egal/egal"))[T.ftrad/megal]     0.1984      0.154      1.286      0.198      -0.104       0.501
# C(both, Treatment(reference="egal/egal"))[T.trad/trad]       0.1647      0.151      1.093      0.274      -0.131       0.460
# ==============================================================================
# Omnibus:                      153.047   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              192.588
# Skew:                          -0.796   Prob(JB):                     1.51e-42
# Kurtosis:                       3.135   Cond. No.                         4.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Step 1:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  fsat5   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     10.14
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):           4.03e-08
# Time:                        22:34:38   Log-Likelihood:                -4144.5
# No. Observations:                1812   AIC:                             8299.
# Df Residuals:                    1807   BIC:                             8327.
# Df Model:                           4
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    7.0003      0.119     58.794      0.000       6.767       7.234
# C(both, Treatment(reference="egal/egal"))[T.fegal/mtrad]     0.0308      0.158      0.194      0.846      -0.280       0.342
# C(both, Treatment(reference="egal/egal"))[T.ftrad/megal]     0.2288      0.153      1.498      0.134      -0.071       0.528
# C(both, Treatment(reference="egal/egal"))[T.trad/trad]       0.2214      0.149      1.482      0.138      -0.072       0.514
# reldur                                                      -0.0034      0.001     -6.179      0.000      -0.004      -0.002
# ==============================================================================
# Omnibus:                      153.602   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              193.465
# Skew:                          -0.798   Prob(JB):                     9.76e-43
# Kurtosis:                       3.134   Cond. No.                         685.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Step 2:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  fsat5   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     16.62
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):           4.44e-16
# Time:                        22:34:38   Log-Likelihood:                -4123.9
# No. Observations:                1812   AIC:                             8260.
# Df Residuals:                    1806   BIC:                             8293.
# Df Model:                           5
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    8.5541      0.268     31.908      0.000       8.028       9.080
# C(both, Treatment(reference="egal/egal"))[T.fegal/mtrad]     0.0166      0.157      0.106      0.916      -0.291       0.324
# C(both, Treatment(reference="egal/egal"))[T.ftrad/megal]     0.2965      0.151      1.958      0.050      -0.001       0.594
# C(both, Treatment(reference="egal/egal"))[T.trad/trad]       0.2533      0.148      1.713      0.087      -0.037       0.543
# reldur                                                       0.0005      0.001      0.647      0.518      -0.001       0.002
# fage                                                        -0.0607      0.009     -6.451      0.000      -0.079      -0.042
# ==============================================================================
# Omnibus:                      140.063   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              172.916
# Skew:                          -0.755   Prob(JB):                     2.83e-38
# Kurtosis:                       3.109   Cond. No.                         899.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Step 3:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  fsat5   R-squared:                       0.284
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     119.1
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):          5.78e-127
# Time:                        22:34:38   Log-Likelihood:                -3862.4
# No. Observations:                1812   AIC:                             7739.
# Df Residuals:                    1805   BIC:                             7777.
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    3.9348      0.299     13.173      0.000       3.349       4.521
# C(both, Treatment(reference="egal/egal"))[T.fegal/mtrad]    -0.0860      0.136     -0.633      0.527      -0.352       0.180
# C(both, Treatment(reference="egal/egal"))[T.ftrad/megal]     0.1674      0.131      1.275      0.202      -0.090       0.425
# C(both, Treatment(reference="egal/egal"))[T.trad/trad]      -0.0193      0.128     -0.150      0.881      -0.271       0.233
# reldur                                                       0.0012      0.001      1.735      0.083      -0.000       0.003
# fage                                                        -0.0190      0.008     -2.288      0.022      -0.035      -0.003
# sex8                                                         0.9310      0.038     24.575      0.000       0.857       1.005
# ==============================================================================
# Omnibus:                       96.007   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              110.312
# Skew:                          -0.587   Prob(JB):                     1.11e-24
# Kurtosis:                       3.287   Cond. No.                     1.13e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.13e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
stepwise("msat5", ['C(both, Treatment(reference="egal/egal"))', "reldur", "mage", "sex8" ], final_df)
# Out:
# Step 0:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  msat5   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.2708
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):              0.846
# Time:                        22:34:38   Log-Likelihood:                -4269.8
# No. Observations:                1812   AIC:                             8548.
# Df Residuals:                    1808   BIC:                             8570.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    6.3694      0.098     64.686      0.000       6.176       6.563
# C(both, Treatment(reference="egal/egal"))[T.fegal/mtrad]    -0.0683      0.170     -0.402      0.688      -0.401       0.265
# C(both, Treatment(reference="egal/egal"))[T.ftrad/megal]     0.0875      0.164      0.535      0.593      -0.233       0.408
# C(both, Treatment(reference="egal/egal"))[T.trad/trad]       0.0591      0.160      0.370      0.711      -0.254       0.372
# ==============================================================================
# Omnibus:                      133.042   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              159.747
# Skew:                          -0.718   Prob(JB):                     2.05e-35
# Kurtosis:                       2.764   Cond. No.                         4.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Step 1:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  msat5   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     18.70
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):           4.51e-15
# Time:                        22:34:39   Log-Likelihood:                -4233.5
# No. Observations:                1812   AIC:                             8477.
# Df Residuals:                    1807   BIC:                             8504.
# Df Model:                           4
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    7.0530      0.125     56.399      0.000       6.808       7.298
# C(both, Treatment(reference="egal/egal"))[T.fegal/mtrad]    -0.0610      0.166     -0.367      0.714      -0.387       0.265
# C(both, Treatment(reference="egal/egal"))[T.ftrad/megal]     0.1319      0.160      0.822      0.411      -0.183       0.447
# C(both, Treatment(reference="egal/egal"))[T.trad/trad]       0.1420      0.157      0.905      0.365      -0.166       0.450
# reldur                                                      -0.0049      0.001     -8.599      0.000      -0.006      -0.004
# ==============================================================================
# Omnibus:                      127.896   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              153.763
# Skew:                          -0.707   Prob(JB):                     4.08e-34
# Kurtosis:                       2.811   Cond. No.                         685.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Step 2:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  msat5   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     18.79
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):           3.00e-18
# Time:                        22:34:39   Log-Likelihood:                -4224.3
# No. Observations:                1812   AIC:                             8461.
# Df Residuals:                    1806   BIC:                             8494.
# Df Model:                           5
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    8.0841      0.270     29.893      0.000       7.554       8.614
# C(both, Treatment(reference="egal/egal"))[T.fegal/mtrad]    -0.0569      0.166     -0.344      0.731      -0.382       0.268
# C(both, Treatment(reference="egal/egal"))[T.ftrad/megal]     0.1878      0.160      1.172      0.241      -0.126       0.502
# C(both, Treatment(reference="egal/egal"))[T.trad/trad]       0.1804      0.156      1.153      0.249      -0.126       0.487
# reldur                                                      -0.0025      0.001     -3.043      0.002      -0.004      -0.001
# mage                                                        -0.0374      0.009     -4.295      0.000      -0.055      -0.020
# ==============================================================================
# Omnibus:                      117.995   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              139.562
# Skew:                          -0.673   Prob(JB):                     4.95e-31
# Kurtosis:                       2.807   Cond. No.                         862.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Step 3:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  msat5   R-squared:                       0.314
# Model:                            OLS   Adj. R-squared:                  0.311
# Method:                 Least Squares   F-statistic:                     137.4
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):          1.47e-143
# Time:                        22:34:39   Log-Likelihood:                -3929.4
# No. Observations:                1812   AIC:                             7873.
# Df Residuals:                    1805   BIC:                             7911.
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    3.0779      0.298     10.320      0.000       2.493       3.663
# C(both, Treatment(reference="egal/egal"))[T.fegal/mtrad]    -0.1858      0.141     -1.319      0.187      -0.462       0.090
# C(both, Treatment(reference="egal/egal"))[T.ftrad/megal]     0.0385      0.136      0.282      0.778      -0.229       0.306
# C(both, Treatment(reference="egal/egal"))[T.trad/trad]      -0.1375      0.134     -1.030      0.303      -0.399       0.124
# reldur                                                      -0.0013      0.001     -1.830      0.067      -0.003    9.05e-05
# mage                                                         0.0011      0.008      0.146      0.884      -0.014       0.016
# sex8                                                         1.0336      0.039     26.350      0.000       0.957       1.111
# ==============================================================================
# Omnibus:                       51.553   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.279
# Skew:                          -0.418   Prob(JB):                     9.92e-13
# Kurtosis:                       3.184   Cond. No.                     1.09e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.09e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
